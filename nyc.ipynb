# %%
print ('hello miles')
# Out:
# hello miles

# %% [markdown]
# install tableone

# %%
pip install tableone
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install researchpy #install researchpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# import libraries

# %%
import pandas as pd
import scipy
from scipy import stats
from pandas.plotting import scatter_matrix
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.express as px
from statsmodels.formula.api import ols
import os
import seaborn
import urllib.request
import patsy
import researchpy as rp
from tableone import TableOne

# %% [markdown]
# define df as dataframe

# %%
df = pd.read_csv('data/Hospital_Inpatient_Discharges__SPARCS_De-Identified___2016 (1).csv')
# Out:
# /var/folders/sn/w009kb0n6zn_x17gcrqvxt2w0000gn/T/ipykernel_5630/440437302.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data/Hospital_Inpatient_Discharges__SPARCS_De-Identified___2016 (1).csv')

# %%
df 
df.shape #rows and columns
# Out:
# (2343429, 34)

# %%
df.columns
df.dtypes #columns and data types
# Out:
# Health Service Area                     object
# Hospital County                         object
# Operating Certificate Number           float64
# Facility Id                            float64
# Facility Name                           object
# Age Group                               object
# Zip Code - 3 digits                     object
# Gender                                  object
# Race                                    object
# Ethnicity                               object
# Length of Stay                          object
# Type of Admission                       object
# Patient Disposition                     object
# Discharge Year                           int64
# CCS Diagnosis Code                       int64
# CCS Diagnosis Description               object
# CCS Procedure Code                       int64
# CCS Procedure Description               object
# APR DRG Code                             int64
# APR DRG Description                     object
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of         Health Service Area Hospital County  Operating Certificate Number  \
# 0                Western NY        Allegany                      226700.0
# 1                Western NY        Allegany                      226700.0
# 2                Western NY        Allegany                      226700.0
# 3                Western NY        Allegany                      226700.0
# 4                Western NY        Allegany                      226700.0
# ...                     ...             ...                           ...
# 2343424         Long Island         Suffolk                     5157003.0
# 2343425         Long Island         Suffolk                     5157003.0
# 2343426         Long Island         Suffolk                     5157003.0
# 2343427         Long Island         Suffolk                     5157003.0
# 2343428         Long Island         Suffolk                     5157003.0
#
# ...

# %%
df.median
df.mean
#describing the df using different variables
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of         Health Service Area Hospital County  Operating Certificate Number  \
# 0                Western NY        Allegany                      226700.0
# 1                Western NY        Allegany                      226700.0
# 2                Western NY        Allegany                      226700.0
# 3                Western NY        Allegany                      226700.0
# 4                Western NY        Allegany                      226700.0
# ...                     ...             ...                           ...
# 2343424         Long Island         Suffolk                     5157003.0
# 2343425         Long Island         Suffolk                     5157003.0
# 2343426         Long Island         Suffolk                     5157003.0
# 2343427         Long Island         Suffolk                     5157003.0
# 2343428         Long Island         Suffolk                     5157003.0
#
# ...

# %% [markdown]
# TableOne attempt

# %%
sparcs = df.copy()
sparcs.dtypes
list(sparcs)
# Out:
# ['Health Service Area',
#  'Hospital County',
#  'Operating Certificate Number',
#  'Facility Id',
#  'Facility Name',
#  'Age Group',
#  'Zip Code - 3 digits',
#  'Gender',
#  'Race',
#  'Ethnicity',
#  'Length of Stay',
#  'Type of Admission',
#  'Patient Disposition',
#  'Discharge Year',
#  'CCS Diagnosis Code',
#  'CCS Diagnosis Description',
#  'CCS Procedure Code',
#  'CCS Procedure Description',
#  'APR DRG Code',
#  'APR DRG Description',
#  'APR MDC Code',
#  'APR MDC Description',
#  'APR Severity of Illness Code',
#  'APR Severity of Illness Description',
#  'APR Risk of Mortality',
#  'APR Medical Surgical Description',
#  'Payment Typology 1',
#  'Payment Typology 2',
#  'Payment Typology 3',
#  'Birth Weight',
#  'Abortion Edit Indicator',
#  'Emergency Department Indicator',
#  'Total Charges',
#  'Total Costs']

# %%
sparcs_columns = ['age_group', 'gender', 'race', 'ethnicity', 'length_of_stay',
'ccs_diagnosis_code', 'ccs_procedure_code', 'apr_severity_of_illness_code']
sparcs_cat = ['age', 'race',]
sparcs_group =['race']

# %% [markdown]
# Researchpy Attempt

# %%
rp.codebook(df)
# Out:
# Variable: Health Service Area    Data Type: object
#
#  Number of Obs.: 2343429
#  Number of missing obs.: 5325
#  Percent missing: 0.23
#  Number of unique values: 8
#
#  Data Values and Counts:
#
#           Values  Frequency
# Capital/Adirond     170134
#      Central NY     158274
#    Finger Lakes     150129
#   Hudson Valley     247612
#     Long Island     342494
#   New York City    1074266
#   Southern Tier      29522
#      Western NY     165673
#
#
#
#
# Variable: Hospital County    Data Type: object
#
#  Number of Obs.: 2343429
#  Number of missing obs.: 5325
#  Percent missing: 0.23
#  Number of unique values: 57
#
#  Data Values and Counts:
#
#       Values  Frequency
#      Albany      69727
#    Allegany       1991
#       Bronx     182839
#      Broome      27958
# Cattaraugus       5529
#      Cayuga       5268
#  Chautauqua      10308
#     Chemung      13242
#    Chenango       1564
#     Clinton       8873
#    Columbia       5556
#    Cortland       3533
# ...

# %%
rp.summary_cont(df['Type of Admission'])
